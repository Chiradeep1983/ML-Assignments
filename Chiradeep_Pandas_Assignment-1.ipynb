# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df['From_To'][0]
# Out:
# 'LoNDon_paris'

# %% [markdown]
# 2. The From_To column would be better as two separate columns! Split each
# string on the underscore delimiter _ to give a new temporary DataFrame with
# the correct values. Assign the correct column names to this temporary
# DataFrame.
# 3. Notice how the capitalisation of the city names is all mixed up in this
# temporary DataFrame. Standardise the strings so that only the first letter is
# uppercase (e.g. "londON" should become "London".)
# 4. Delete the From_To column from df and attach the temporary DataFrame
# from the previous questions.

# %%
#split From_to Column to From and To Column separately

s_dat=df['From_To'].str.split("_")
w_data1= s_dat.to_list()   
c_names=["From_City","To_City"]
n_data=pd.DataFrame(w_data1, columns=c_names)
print(n_data)
for x in n_data["From_City"]:
    n_data["From_City"] = n_data["From_City"].str.lower() 
for x in n_data["To_City"]:
    n_data["To_City"] = n_data["To_City"].str.lower() 
    
for x in n_data["To_City"]:
    n_data["To_City"] = n_data["To_City"].str.title() 

for x in n_data["From_City"]:
    n_data["From_City"] = n_data["From_City"].str.title() 
result=pd.concat([n_data,df],axis=1, sort=False)
result.drop(["From_To"], axis=1)
# Out:
#   From_City    To_City
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn
#   From_City    To_City  FlightNumber  RecentDelays              Airline
# 0    London      Paris       10045.0      [23, 47]               KLM(!)
# 1    Madrid      Milan           NaN            []    <Air France> (12)
# 2    London  Stockholm       10065.0  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris           NaN          [13]       12. Air France
# 4  Brussels     London       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# 1. Some values in the the FlightNumber column are missing. These numbers are
# meant to increase by 10 with each row so 10055 and 10075 need to be put in
# place. Fill in these missing numbers and make the column an integer column
# (instead of a float column).

# %%
result["FlightNumber"]=result["FlightNumber"].interpolate()
result["FlightNumber"]=result["FlightNumber"].round(0).astype(int)
result
# Out:
#   From_City    To_City           From_To  FlightNumber  RecentDelays  \
# 0    London      Paris      LoNDon_paris         10045      [23, 47]
# 1    Madrid      Milan      MAdrid_miLAN         10055            []
# 2    London  Stockholm  londON_StockhOlm         10065  [24, 43, 87]
# 3  Budapest      Paris    Budapest_PaRis         10075          [13]
# 4  Brussels     London   Brussels_londOn         10085      [67, 32]
#
#                Airline
# 0               KLM(!)
# 1    <Air France> (12)
# 2  (British Airways. )
# 3       12. Air France
# 4          "Swiss Air"

# %% [markdown]
# 5. In the RecentDelays column, the values have been entered into the
# DataFrame as a list. We would like each first value in its own column, each
# second value in its own column, and so on. If there isn't an Nth value, the value
# should be NaN.
# Expand the Series of lists into a DataFrame named delays, rename the columns
# delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df
# with delays.

# %%
result[['delay_1', 'delay_2',"delay_3"]] = pd.DataFrame(result.RecentDelays.tolist(), index= result.index)
result=result.drop(["RecentDelays","From_To"],axis=1)
result
# Out:
#   From_City    To_City  FlightNumber              Airline  delay_1  delay_2  \
# 0    London      Paris         10045               KLM(!)     23.0     47.0
# 1    Madrid      Milan         10055    <Air France> (12)      NaN      NaN
# 2    London  Stockholm         10065  (British Airways. )     24.0     43.0
# 3  Budapest      Paris         10075       12. Air France     13.0      NaN
# 4  Brussels     London         10085          "Swiss Air"     67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN

# %%
##Extra lets clean the Airline
chars=["''","12",".","(",")","!","<",">",'"']
for char in chars:
    result['Airline'] = result['Airline'].str.replace(char, ' ')
result
# Out:
#   From_City    To_City  FlightNumber              Airline  delay_1  delay_2  \
# 0    London      Paris         10045               KLM        23.0     47.0
# 1    Madrid      Milan         10055      Air France           NaN      NaN
# 2    London  Stockholm         10065   British Airways        24.0     43.0
# 3  Budapest      Paris         10075           Air France     13.0      NaN
# 4  Brussels     London         10085           Swiss Air      67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN
